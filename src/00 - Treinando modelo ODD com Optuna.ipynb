# %%
# Printa a versão do Python
import sys
print(f"Versão do Python: {sys.version}")
# Out:
# Versão do Python: 3.11.7 (tags/v3.11.7:fa7a6f2, Dec  4 2023, 19:24:49) [MSC v.1937 64 bit (AMD64)]

# %%
# Importa as bibliotecas
import os
import pickle

import numpy as np
import pandas as pd

import torch as th

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %matplotlib inline

print(f"Versão do PyTorch: {th.__version__}")
# Out:
# Versão do PyTorch: 2.1.2+cpu

# %%
from Enviroment.Settings import *
from Enviroment.Manager import Enviroment

# %%
from stable_baselines3 import PPO

# %%
from stable_baselines3.common.env_util import make_vec_env, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# Importando o Monitor
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

print(f"Versão do Gymnasium: {gym.__version__}")
# Out:
# Versão do Gymnasium: 0.29.1

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from optuna.visualization import plot_optimization_history, plot_param_importances

# %%
N_TRIALS = 200  # Maximum number of trials
N_JOBS = 1 # Number of jobs to run in parallel
N_STARTUP_TRIALS = 10  # Stop random sampling after N_STARTUP_TRIALS
N_EVALUATIONS = 5  # Number of evaluations during the training
N_TIMESTEPS = int(5e5)  # Training budget
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_ENVS = 5
N_EVAL_EPISODES = 10
TIMEOUT = int(60 * 60 * 24 * 4)  # 4 dias 

enviroment_type = {
    "Observation": "ODD-one-hot",
    "Action": "RSA-SAR",
    "Reward": "RL-defaut",
    "StopCond": "40kReqs",
    "StartCond": "Empty"
}

env = Enviroment(
    network_load=300,
    k_routes=3,
    number_of_slots=128,
    enviroment_type=enviroment_type,
    data_folder="Train_PPO_Optuna",
)

#env = Monitor(DummyVecEnv(env))

DEFAULT_HYPERPARAMS = {
    "policy": "MlpPolicy",
    "env": env,
}

# %%
from typing import Any, Dict
import torch
import torch.nn as nn

def sample_PPO_params(trial: optuna.Trial) -> Dict[str, Any]:
    """
    Sampler for PPO hyperparameters.

    :param trial: Optuna trial object
    :return: The sampled hyperparameters for the given trial.
    """
    learning_rate = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    # 16, 32, ... 16384
    n_steps = 2 ** trial.suggest_int("exponent_n_steps", 4, 14)
    batch_size = 2 ** trial.suggest_int("exponent_batch_size", 4, 11)
    # Discount factor between 0.9 and 0.9999
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    ent_coef = trial.suggest_float('ent_coef', 0.0001, 0.1, log=True)
    clip_range = trial.suggest_float('clip_range', 0.1, 0.4)
    vf_coef = trial.suggest_float('vf_coef', 0.25, 0.75)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.1, 10.0, log=True)
    gae_lambda = trial.suggest_float("gae_lambda", 0.8, 0.99)
    n_epochs = trial.suggest_int("n_epochs", 2, 10)
    clip_range_vf = trial.suggest_float("clip_range_vf", 0.1, 0.4)

    net_arch = trial.suggest_categorical("net_arch", ["tiny", "small"])
    activation_fn = trial.suggest_categorical("activation_fn", ["tanh", "relu"])

    # Display true values
    trial.set_user_attr("gamma", gamma)
    trial.set_user_attr("n_steps", n_steps)
    trial.set_user_attr("batch_size", batch_size)

    net_arch = [
        {"pi": [128], "vf": [128]}
        if net_arch == "tiny"
        else {"pi": [256, 256], "vf": [256, 256]}
    ]

    activation_fn = {"tanh": nn.Tanh, "relu": nn.ReLU}[activation_fn]

    return {
        "learning_rate": learning_rate,
        "n_steps": n_steps,
        "batch_size": batch_size,
        "gamma": gamma,
        "ent_coef": ent_coef,
        "clip_range": clip_range,
        "vf_coef": vf_coef,
        "max_grad_norm": max_grad_norm,
        "gae_lambda": gae_lambda,
        "n_epochs": n_epochs,
        "clip_range_vf": clip_range_vf,
        "policy_kwargs": {
            "net_arch": net_arch,
            "activation_fn": activation_fn,
        },
    }

# %%
from stable_baselines3.common.callbacks import EvalCallback

class TrialEvalCallback(EvalCallback):
    """
    Callback used for evaluating and reporting a trial.
    
    :param eval_env: Evaluation environement
    :param trial: Optuna trial object
    :param n_eval_episodes: Number of evaluation episodes
    :param eval_freq:   Evaluate the agent every ``eval_freq`` call of the callback.
    :param deterministic: Whether the evaluation should
        use a stochastic or deterministic policy.
    :param verbose:
    """

    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 40_000,
        deterministic: bool = True,
        verbose: int = 0,
    ):

        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            # Evaluate policy (done in the parent class)
            super()._on_step()
            self.eval_idx += 1
            # Send report to Optuna
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %%
def objective(trial: optuna.Trial) -> float:
    """
    Objective function using by Optuna to evaluate
    one configuration (i.e., one set of hyperparameters).

    Given a trial object, it will sample hyperparameters,
    evaluate it and report the result (mean episodic reward after training)

    :param trial: Optuna trial object
    :return: Mean episodic reward after training
    """

    kwargs = DEFAULT_HYPERPARAMS.copy()
    ### YOUR CODE HERE
    # TODO: 
    # 1. Sample hyperparameters and update the default keyword arguments: `kwargs.update(other_params)`
    # 2. Create the evaluation envs
    # 3. Create the `TrialEvalCallback`

    # 1. Sample hyperparameters and update the keyword arguments
    kwargs.update(sample_PPO_params(trial))

    # Create the RL model
    model = PPO(**kwargs)

    # 2. Create envs used for evaluation using `make_vec_env`, `ENV_ID` and `N_EVAL_ENVS`
    #eval_envs = make_vec_env(env, N_EVAL_ENVS)

    # 3. Create the `TrialEvalCallback` callback defined above that will periodically evaluate
    # and report the performance using `N_EVAL_EPISODES` every `EVAL_FREQ`
    # TrialEvalCallback signature:
    # TrialEvalCallback(eval_env, trial, n_eval_episodes, eval_freq, deterministic, verbose)
    eval_callback = TrialEvalCallback(env, trial, N_EVAL_EPISODES, EVAL_FREQ, True)

    ### END OF YOUR CODE

    nan_encountered = False
    try:
        # Train the model
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN
        print(e)
        nan_encountered = True
    finally:
        # Free memory
        model.env.close()
        #eval_envs.close()

    # Tell the optimizer that the trial failed
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward

# %%
import torch as th

# Set pytorch num threads to 1 for faster training
th.set_num_threads(1)
# Select the sampler, can be random, TPESampler, CMAES, ...
sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
# Do not prune before 1/3 of the max budget is used
pruner = MedianPruner(
    n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3
)
# Create the study and start the hyperparameter optimization
study = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize", study_name="ODD_RSA_RSA_v2", storage="sqlite:///ODD_RSA_RSA.db")

try:
    study.optimize(objective, n_trials=N_TRIALS, n_jobs=N_JOBS, timeout=TIMEOUT)
except KeyboardInterrupt:
    pass

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")

print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

print("  User attrs:")
for key, value in trial.user_attrs.items():
    print(f"    {key}: {value}")

# Write report
study.trials_dataframe().to_csv("study_results_a2c_cartpole.csv")

fig1 = plot_optimization_history(study)
fig2 = plot_param_importances(study)

fig1.show()
fig2.show()
# Out:
# [I 2024-02-17 19:22:55,773] A new study created in RDB with name: ODD_RSA_RSA_v2
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\common\policies.py:484: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# [I 2024-02-17 19:41:19,939] Trial 0 finished with value: 39068.8 and parameters: {'lr': 0.04215543478822348, 'exponent_n_steps': 6, 'exponent_batch_size': 10, 'gamma': 0.011317521612295727, 'ent_coef': 0.0393591015778859, 'clip_range': 0.1246557090351708, 'vf_coef': 0.6037697852131467, 'max_grad_norm': 0.3199427715498113, 'gae_lambda': 0.9350645937170587, 'n_epochs': 3, 'clip_range_vf': 0.22247243287281415, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 19:55:52,045] Trial 1 finished with value: 38907.2 and parameters: {'lr': 0.0018968157551203775, 'exponent_n_steps': 14, 'exponent_batch_size': 6, 'gamma': 0.001424434565712118, 'ent_coef': 0.017136362610545654, 'clip_range': 0.10564938811324355, 'vf_coef': 0.34906201025991646, 'max_grad_norm': 7.10430721640414, 'gae_lambda': 0.8102776570659359, 'n_epochs': 2, 'clip_range_vf': 0.36487893708982944, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 20:13:46,187] Trial 2 finished with value: 38877.8 and parameters: {'lr': 2.2727963729895164e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 5, 'gamma': 0.00016529805322867014, 'ent_coef': 0.00033066389090534605, 'clip_range': 0.2983833071842641, 'vf_coef': 0.4253883303767756, 'max_grad_norm': 1.4084206717473817, 'gae_lambda': 0.9641024368418102, 'n_epochs': 2, 'clip_range_vf': 0.11038767119089497, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-17 20:35:27,953] Trial 3 finished with value: 38781.6 and parameters: {'lr': 0.0049032345643538295, 'exponent_n_steps': 4, 'exponent_batch_size': 10, 'gamma': 0.01627307326900805, 'ent_coef': 0.0002797375694101865, 'clip_range': 0.2813924235525396, 'vf_coef': 0.6725517932385009, 'max_grad_norm': 0.1778351120357222, 'gae_lambda': 0.9263190679212723, 'n_epochs': 7, 'clip_range_vf': 0.34408715026164605, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 20:57:12,491] Trial 4 finished with value: 38976.2 and parameters: {'lr': 8.358880527300128e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 6, 'gamma': 0.01358816521273615, 'ent_coef': 0.0011345701102715789, 'clip_range': 0.12417196820627274, 'vf_coef': 0.6273365367993149, 'max_grad_norm': 7.39773516701029, 'gae_lambda': 0.8633429591555067, 'n_epochs': 9, 'clip_range_vf': 0.13424434522065049, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 21:11:34,659] Trial 5 finished with value: 39039.0 and parameters: {'lr': 0.004771165411439669, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.02787126297387081, 'ent_coef': 0.02474673397354421, 'clip_range': 0.2556677159140973, 'vf_coef': 0.6453156344057307, 'max_grad_norm': 9.346470196099691, 'gae_lambda': 0.9406912377866171, 'n_epochs': 8, 'clip_range_vf': 0.16879417204609531, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 21:29:47,129] Trial 6 finished with value: 38897.0 and parameters: {'lr': 0.02990630363964005, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.0007467478320865028, 'ent_coef': 0.015102537879546596, 'clip_range': 0.34195807491747976, 'vf_coef': 0.5160722341529868, 'max_grad_norm': 1.911481895871703, 'gae_lambda': 0.8204644011854026, 'n_epochs': 10, 'clip_range_vf': 0.3814345704536878, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 21:50:23,207] Trial 7 finished with value: 39039.2 and parameters: {'lr': 0.0038706923003320294, 'exponent_n_steps': 11, 'exponent_batch_size': 6, 'gamma': 0.00024879825706231533, 'ent_coef': 0.00014339771901027208, 'clip_range': 0.3039749020295882, 'vf_coef': 0.4252505381403867, 'max_grad_norm': 5.6278516113346315, 'gae_lambda': 0.804457556847767, 'n_epochs': 7, 'clip_range_vf': 0.37552753840487985, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 22:07:16,956] Trial 8 finished with value: 38880.2 and parameters: {'lr': 0.0018949370940191013, 'exponent_n_steps': 8, 'exponent_batch_size': 6, 'gamma': 0.0002020673209979791, 'ent_coef': 0.0019061542926908444, 'clip_range': 0.3675755651219371, 'vf_coef': 0.4914453455622964, 'max_grad_norm': 6.761002790305637, 'gae_lambda': 0.9530281600610213, 'n_epochs': 10, 'clip_range_vf': 0.18118337488512848, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 22:21:29,381] Trial 9 finished with value: 38914.8 and parameters: {'lr': 0.00042695378345492045, 'exponent_n_steps': 14, 'exponent_batch_size': 7, 'gamma': 0.03634748678323033, 'ent_coef': 0.0011626414478127817, 'clip_range': 0.3293626631423418, 'vf_coef': 0.7390746821547862, 'max_grad_norm': 3.520653704856461, 'gae_lambda': 0.9089500243619572, 'n_epochs': 3, 'clip_range_vf': 0.2385345171106016, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 0 with value: 39068.8.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-17 22:25:37,131] Trial 10 pruned.
# [I 2024-02-17 23:04:15,670] Trial 11 finished with value: 39006.4 and parameters: {'lr': 0.015161232451028296, 'exponent_n_steps': 6, 'exponent_batch_size': 4, 'gamma': 0.004928285404577769, 'ent_coef': 0.00010537903047435022, 'clip_range': 0.18881851463073904, 'vf_coef': 0.5267655127444363, 'max_grad_norm': 0.5093192991784703, 'gae_lambda': 0.8817356905625837, 'n_epochs': 5, 'clip_range_vf': 0.29576538383263673, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 23:11:55,104] Trial 12 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-17 23:31:52,767] Trial 13 finished with value: 39051.0 and parameters: {'lr': 0.013161813643661728, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0005573973762800666, 'ent_coef': 0.0886267969538185, 'clip_range': 0.2296013046582429, 'vf_coef': 0.5594801534277997, 'max_grad_norm': 0.17512620199357273, 'gae_lambda': 0.9016691409247295, 'n_epochs': 6, 'clip_range_vf': 0.22607470364531262, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# [I 2024-02-17 23:35:32,929] Trial 14 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 512, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-17 23:39:45,860] Trial 15 pruned.
# [I 2024-02-17 23:58:21,151] Trial 16 finished with value: 39040.6 and parameters: {'lr': 0.09683439446576325, 'exponent_n_steps': 9, 'exponent_batch_size': 9, 'gamma': 0.0005079387510397198, 'ent_coef': 0.006668486986606825, 'clip_range': 0.15565061370995234, 'vf_coef': 0.733789537842163, 'max_grad_norm': 0.11668056866175798, 'gae_lambda': 0.9289668915379903, 'n_epochs': 4, 'clip_range_vf': 0.27627741418087115, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: 39068.8.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 00:04:58,621] Trial 17 pruned.
# [I 2024-02-18 00:08:29,327] Trial 18 pruned.
# [I 2024-02-18 00:12:23,876] Trial 19 pruned.
# [I 2024-02-18 00:31:10,985] Trial 20 finished with value: 39084.6 and parameters: {'lr': 0.010537612099536851, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.009063692921985578, 'ent_coef': 0.09516521225949003, 'clip_range': 0.38867495691989384, 'vf_coef': 0.5990908605980592, 'max_grad_norm': 0.3378645404317244, 'gae_lambda': 0.9245710380604207, 'n_epochs': 5, 'clip_range_vf': 0.25795640732845704, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 00:34:52,050] Trial 21 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 512, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 00:38:57,214] Trial 22 pruned.
# [I 2024-02-18 00:42:46,945] Trial 23 pruned.
# [I 2024-02-18 00:46:10,905] Trial 24 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 00:50:31,502] Trial 25 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 00:53:20,739] Trial 26 pruned.
# [I 2024-02-18 01:09:16,082] Trial 27 finished with value: 38981.2 and parameters: {'lr': 0.052210194087487026, 'exponent_n_steps': 9, 'exponent_batch_size': 9, 'gamma': 0.01842340100227701, 'ent_coef': 0.0525416840878906, 'clip_range': 0.2479059556939211, 'vf_coef': 0.6456985500473081, 'max_grad_norm': 0.13867865173850988, 'gae_lambda': 0.9643391167632441, 'n_epochs': 3, 'clip_range_vf': 0.27540063112890134, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 128, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 01:26:20,555] Trial 28 finished with value: 39061.4 and parameters: {'lr': 0.018675360062357257, 'exponent_n_steps': 6, 'exponent_batch_size': 7, 'gamma': 0.00010762634267830869, 'ent_coef': 0.010512616690482108, 'clip_range': 0.1052972708448368, 'vf_coef': 0.594221736258896, 'max_grad_norm': 0.25749693093246423, 'gae_lambda': 0.8961166972349575, 'n_epochs': 2, 'clip_range_vf': 0.14631032007641068, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 01:29:14,995] Trial 29 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 128, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 01:32:42,030] Trial 30 pruned.
# [I 2024-02-18 01:35:55,398] Trial 31 pruned.
# [I 2024-02-18 01:54:34,354] Trial 32 finished with value: 39061.8 and parameters: {'lr': 1.210494480721214e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 5, 'gamma': 0.0013314656856228111, 'ent_coef': 0.021265082094496193, 'clip_range': 0.101701773643967, 'vf_coef': 0.6475377139175008, 'max_grad_norm': 0.20213849855021088, 'gae_lambda': 0.8909806978842126, 'n_epochs': 3, 'clip_range_vf': 0.23716003238520872, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 01:58:41,225] Trial 33 pruned.
# [I 2024-02-18 02:02:03,433] Trial 34 pruned.
# [I 2024-02-18 02:19:15,788] Trial 35 finished with value: 38844.8 and parameters: {'lr': 0.00027282768607292407, 'exponent_n_steps': 5, 'exponent_batch_size': 5, 'gamma': 0.016752289100818402, 'ent_coef': 0.022365093865099165, 'clip_range': 0.1254993405695483, 'vf_coef': 0.6264195472441498, 'max_grad_norm': 0.3199355940784004, 'gae_lambda': 0.891772575534264, 'n_epochs': 2, 'clip_range_vf': 0.1500180888707366, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 02:34:24,492] Trial 36 finished with value: 39046.2 and parameters: {'lr': 2.126813079481733e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 6, 'gamma': 0.0011826925311111986, 'ent_coef': 0.0032590138325692295, 'clip_range': 0.14799232279055624, 'vf_coef': 0.6732297381859152, 'max_grad_norm': 0.6390838877113649, 'gae_lambda': 0.9184680632765627, 'n_epochs': 4, 'clip_range_vf': 0.3503252938674035, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 02:57:47,578] Trial 37 finished with value: 38996.8 and parameters: {'lr': 0.0036568338807897137, 'exponent_n_steps': 6, 'exponent_batch_size': 4, 'gamma': 0.00011275085699709147, 'ent_coef': 0.01355512914161121, 'clip_range': 0.29524023313292225, 'vf_coef': 0.6332605867725096, 'max_grad_norm': 0.18565534597344044, 'gae_lambda': 0.9514000233884572, 'n_epochs': 3, 'clip_range_vf': 0.11285807940282014, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 03:00:55,556] Trial 38 pruned.
# [I 2024-02-18 03:03:48,489] Trial 39 pruned.
# [I 2024-02-18 03:07:19,933] Trial 40 pruned.
# [I 2024-02-18 03:10:55,122] Trial 41 pruned.
# [I 2024-02-18 03:14:39,445] Trial 42 pruned.
# [I 2024-02-18 03:32:37,357] Trial 43 finished with value: 39037.0 and parameters: {'lr': 0.04367096090875341, 'exponent_n_steps': 7, 'exponent_batch_size': 10, 'gamma': 0.0007524731278474773, 'ent_coef': 0.06118306840429333, 'clip_range': 0.30983533971622396, 'vf_coef': 0.5899757059434444, 'max_grad_norm': 3.198673381051115, 'gae_lambda': 0.9027572377232578, 'n_epochs': 5, 'clip_range_vf': 0.21846627136103247, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 03:52:19,332] Trial 44 finished with value: 39053.0 and parameters: {'lr': 0.018160694225673863, 'exponent_n_steps': 6, 'exponent_batch_size': 6, 'gamma': 0.0001418834566683798, 'ent_coef': 0.09237974805849482, 'clip_range': 0.27446173589320433, 'vf_coef': 0.5517178530094752, 'max_grad_norm': 0.11080048959351689, 'gae_lambda': 0.8803349280602689, 'n_epochs': 6, 'clip_range_vf': 0.39995951037185545, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 03:57:44,232] Trial 45 pruned.
# [I 2024-02-18 04:01:52,856] Trial 46 pruned.
# [I 2024-02-18 04:17:33,781] Trial 47 finished with value: 38992.4 and parameters: {'lr': 0.005177319743795268, 'exponent_n_steps': 5, 'exponent_batch_size': 5, 'gamma': 0.00014061965418877382, 'ent_coef': 0.04463490794043869, 'clip_range': 0.36252106437121545, 'vf_coef': 0.5892048160039384, 'max_grad_norm': 0.2614528082814606, 'gae_lambda': 0.8508980750673572, 'n_epochs': 3, 'clip_range_vf': 0.36961262154238417, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 04:21:28,881] Trial 48 pruned.
# [I 2024-02-18 04:24:49,842] Trial 49 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 04:29:00,081] Trial 50 pruned.
# [I 2024-02-18 04:32:35,888] Trial 51 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 04:36:23,184] Trial 52 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 512, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 04:39:55,856] Trial 53 pruned.
# [I 2024-02-18 04:43:49,377] Trial 54 pruned.
# [I 2024-02-18 04:47:22,420] Trial 55 pruned.
# [I 2024-02-18 04:52:10,152] Trial 56 pruned.
# [I 2024-02-18 04:55:32,808] Trial 57 pruned.
# [I 2024-02-18 05:16:04,298] Trial 58 finished with value: 39040.0 and parameters: {'lr': 0.059967481752801054, 'exponent_n_steps': 5, 'exponent_batch_size': 11, 'gamma': 0.0004493343360225776, 'ent_coef': 0.008756645518832045, 'clip_range': 0.2744059805916239, 'vf_coef': 0.6998390284346359, 'max_grad_norm': 0.35560507175145517, 'gae_lambda': 0.8869421361792214, 'n_epochs': 4, 'clip_range_vf': 0.30084026126936125, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 05:18:59,556] Trial 59 pruned.
# [I 2024-02-18 05:22:54,317] Trial 60 pruned.
# [I 2024-02-18 05:25:58,256] Trial 61 pruned.
# [I 2024-02-18 05:28:51,203] Trial 62 pruned.
# [I 2024-02-18 05:43:48,203] Trial 63 finished with value: 39059.8 and parameters: {'lr': 2.155291668639457e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0008530320778858593, 'ent_coef': 0.0007105641786008348, 'clip_range': 0.15792467261259735, 'vf_coef': 0.6691874756134468, 'max_grad_norm': 1.004589385525048, 'gae_lambda': 0.898639534860349, 'n_epochs': 5, 'clip_range_vf': 0.2318644966566259, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 20 with value: 39084.6.
# [I 2024-02-18 05:58:47,757] Trial 64 finished with value: 39101.4 and parameters: {'lr': 3.240817843698623e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0008027656785736489, 'ent_coef': 0.0001899484641387907, 'clip_range': 0.13399956493573578, 'vf_coef': 0.6395307341097642, 'max_grad_norm': 1.1240988009356605, 'gae_lambda': 0.8993673780839393, 'n_epochs': 6, 'clip_range_vf': 0.2327530358366276, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 06:13:37,137] Trial 65 finished with value: 39065.0 and parameters: {'lr': 3.3175115994584916e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0007922421827683123, 'ent_coef': 0.00017031062536620182, 'clip_range': 0.10004824687550276, 'vf_coef': 0.6400350026260011, 'max_grad_norm': 1.2349202139296684, 'gae_lambda': 0.8760874183157275, 'n_epochs': 6, 'clip_range_vf': 0.24420884067803947, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 06:16:30,556] Trial 66 pruned.
# [I 2024-02-18 06:19:18,586] Trial 67 pruned.
# [I 2024-02-18 06:33:59,280] Trial 68 finished with value: 38962.8 and parameters: {'lr': 9.462934075948251e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0372090791838572, 'ent_coef': 0.00015683361161225096, 'clip_range': 0.11598007598305435, 'vf_coef': 0.6400927262830219, 'max_grad_norm': 2.372040156480207, 'gae_lambda': 0.8669982276114876, 'n_epochs': 6, 'clip_range_vf': 0.2392198683847177, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 06:36:51,356] Trial 69 pruned.
# [I 2024-02-18 06:39:47,656] Trial 70 pruned.
# [I 2024-02-18 06:54:29,031] Trial 71 finished with value: 38913.4 and parameters: {'lr': 1.4285012294049293e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 7, 'gamma': 0.00040714007150580747, 'ent_coef': 0.00011019976094541671, 'clip_range': 0.1281061307066376, 'vf_coef': 0.6247145678446383, 'max_grad_norm': 1.3212213640879118, 'gae_lambda': 0.8780032718743049, 'n_epochs': 6, 'clip_range_vf': 0.20457908690980112, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 06:57:31,886] Trial 72 pruned.
# [I 2024-02-18 07:15:52,196] Trial 73 pruned.
# [I 2024-02-18 07:18:57,957] Trial 74 pruned.
# [I 2024-02-18 07:22:00,304] Trial 75 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 256`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 256
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=256 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 07:24:42,756] Trial 76 pruned.
# [I 2024-02-18 07:27:41,974] Trial 77 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 07:30:58,181] Trial 78 pruned.
# [I 2024-02-18 07:34:06,880] Trial 79 pruned.
# [I 2024-02-18 07:37:35,756] Trial 80 pruned.
# [I 2024-02-18 07:55:36,920] Trial 81 finished with value: 39026.6 and parameters: {'lr': 0.00991424895850455, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.0005053732721335291, 'ent_coef': 0.060213545689535256, 'clip_range': 0.19163143626303372, 'vf_coef': 0.5986544834600693, 'max_grad_norm': 0.21626991705641402, 'gae_lambda': 0.899786778805518, 'n_epochs': 6, 'clip_range_vf': 0.2219528463383911, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 07:59:19,891] Trial 82 pruned.
# [I 2024-02-18 08:03:18,780] Trial 83 pruned.
# [I 2024-02-18 08:06:47,257] Trial 84 pruned.
# [I 2024-02-18 08:10:18,377] Trial 85 pruned.
# [I 2024-02-18 08:13:54,477] Trial 86 pruned.
# [I 2024-02-18 08:17:55,595] Trial 87 pruned.
# [I 2024-02-18 08:36:27,551] Trial 88 finished with value: 38829.6 and parameters: {'lr': 0.02078593462549715, 'exponent_n_steps': 6, 'exponent_batch_size': 8, 'gamma': 0.0023850711890678732, 'ent_coef': 0.09968937871237962, 'clip_range': 0.1116127928922586, 'vf_coef': 0.4963986845513289, 'max_grad_norm': 0.11457048420701896, 'gae_lambda': 0.9040907463501382, 'n_epochs': 5, 'clip_range_vf': 0.1685454677405481, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 08:39:51,465] Trial 89 pruned.
# [I 2024-02-18 08:44:57,545] Trial 90 pruned.
# [I 2024-02-18 09:02:32,192] Trial 91 finished with value: 38987.0 and parameters: {'lr': 2.307973123845628e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 5, 'gamma': 0.001134947933980366, 'ent_coef': 0.0034587421154607125, 'clip_range': 0.1811081800409579, 'vf_coef': 0.6713069087983435, 'max_grad_norm': 1.4971814821818434, 'gae_lambda': 0.9183042292833392, 'n_epochs': 4, 'clip_range_vf': 0.38213991878753173, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 09:19:04,954] Trial 92 finished with value: 38876.4 and parameters: {'lr': 4.7742059129586736e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 6, 'gamma': 0.005702198511777866, 'ent_coef': 0.0012662466750504194, 'clip_range': 0.14592370206736596, 'vf_coef': 0.6483955670982999, 'max_grad_norm': 0.6490359615694355, 'gae_lambda': 0.9133849479600155, 'n_epochs': 3, 'clip_range_vf': 0.35091871467693986, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 09:35:13,461] Trial 93 finished with value: 38884.8 and parameters: {'lr': 2.9921716212218947e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 6, 'gamma': 0.0013737905158725592, 'ent_coef': 0.007764842322454419, 'clip_range': 0.3763013412646514, 'vf_coef': 0.6327084628154566, 'max_grad_norm': 0.7707329890599738, 'gae_lambda': 0.9253708820572945, 'n_epochs': 4, 'clip_range_vf': 0.2216371144285384, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 09:38:16,967] Trial 94 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 512`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 512
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=512 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 09:41:18,823] Trial 95 pruned.
# [I 2024-02-18 09:46:02,004] Trial 96 pruned.
# [I 2024-02-18 09:49:45,197] Trial 97 pruned.
# [I 2024-02-18 09:52:57,671] Trial 98 pruned.
# [I 2024-02-18 09:56:40,088] Trial 99 pruned.
# [I 2024-02-18 09:59:52,771] Trial 100 pruned.
# [I 2024-02-18 10:03:31,176] Trial 101 pruned.
# [I 2024-02-18 10:07:11,983] Trial 102 pruned.
# [I 2024-02-18 10:25:14,775] Trial 103 finished with value: 39030.4 and parameters: {'lr': 0.06887436628102687, 'exponent_n_steps': 9, 'exponent_batch_size': 10, 'gamma': 0.0005760860545737206, 'ent_coef': 0.010349118602657551, 'clip_range': 0.15755450843838462, 'vf_coef': 0.7349028778179303, 'max_grad_norm': 0.1424221826776309, 'gae_lambda': 0.9295353648668301, 'n_epochs': 3, 'clip_range_vf': 0.2426501215134632, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 10:43:46,053] Trial 104 finished with value: 38909.8 and parameters: {'lr': 2.4223248692245496e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 9, 'gamma': 0.01151892466805983, 'ent_coef': 0.003464821696134801, 'clip_range': 0.1404704070971688, 'vf_coef': 0.6240724072603312, 'max_grad_norm': 0.12490875654542546, 'gae_lambda': 0.9020340255190379, 'n_epochs': 5, 'clip_range_vf': 0.25829193958610563, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 10:47:31,684] Trial 105 pruned.
# [I 2024-02-18 10:51:07,123] Trial 106 pruned.
# [I 2024-02-18 10:54:22,688] Trial 107 pruned.
# [I 2024-02-18 10:58:20,795] Trial 108 pruned.
# [I 2024-02-18 11:02:37,927] Trial 109 pruned.
# [I 2024-02-18 11:05:54,013] Trial 110 pruned.
# [I 2024-02-18 11:10:14,678] Trial 111 pruned.
# [I 2024-02-18 11:14:30,787] Trial 112 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 11:18:37,656] Trial 113 pruned.
# [I 2024-02-18 11:22:19,841] Trial 114 pruned.
# [I 2024-02-18 11:27:41,653] Trial 115 pruned.
# [I 2024-02-18 11:31:37,534] Trial 116 pruned.
# [I 2024-02-18 11:34:52,456] Trial 117 pruned.
# [I 2024-02-18 11:55:32,621] Trial 118 finished with value: 38775.2 and parameters: {'lr': 0.016325249267218473, 'exponent_n_steps': 6, 'exponent_batch_size': 7, 'gamma': 0.0009096698784525775, 'ent_coef': 0.08937798229816754, 'clip_range': 0.19068655368187012, 'vf_coef': 0.606310183491418, 'max_grad_norm': 0.12807054163867387, 'gae_lambda': 0.8026608606021712, 'n_epochs': 4, 'clip_range_vf': 0.21061700973666125, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 11:59:11,374] Trial 119 pruned.
# [I 2024-02-18 12:02:23,697] Trial 120 pruned.
# [I 2024-02-18 12:06:56,176] Trial 121 pruned.
# [I 2024-02-18 12:11:37,242] Trial 122 pruned.
# [I 2024-02-18 12:16:44,303] Trial 123 pruned.
# [I 2024-02-18 12:20:56,451] Trial 124 pruned.
# [I 2024-02-18 12:24:42,653] Trial 125 pruned.
# [I 2024-02-18 12:28:14,784] Trial 126 pruned.
# [I 2024-02-18 12:31:22,640] Trial 127 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 128, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 12:36:48,601] Trial 128 pruned.
# [I 2024-02-18 12:39:49,119] Trial 129 pruned.
# [I 2024-02-18 12:58:10,328] Trial 130 finished with value: 38754.6 and parameters: {'lr': 0.013547857347162956, 'exponent_n_steps': 8, 'exponent_batch_size': 8, 'gamma': 0.0006422661387498302, 'ent_coef': 0.025807123490118718, 'clip_range': 0.10930501871450198, 'vf_coef': 0.4636818370385386, 'max_grad_norm': 5.9959834499405025, 'gae_lambda': 0.8661451644488816, 'n_epochs': 6, 'clip_range_vf': 0.30344768205501677, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 13:01:31,716] Trial 131 pruned.
# [I 2024-02-18 13:04:40,278] Trial 132 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 1024`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 1024
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1024 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 13:07:53,230] Trial 133 pruned.
# [I 2024-02-18 13:11:34,891] Trial 134 pruned.
# [I 2024-02-18 13:15:01,503] Trial 135 pruned.
# [I 2024-02-18 13:22:41,591] Trial 136 pruned.
# [I 2024-02-18 13:50:45,137] Trial 137 finished with value: 39027.0 and parameters: {'lr': 1.0135363430315785e-05, 'exponent_n_steps': 5, 'exponent_batch_size': 6, 'gamma': 0.022365802807209848, 'ent_coef': 0.078055504789999, 'clip_range': 0.2217484060862604, 'vf_coef': 0.6846822436475569, 'max_grad_norm': 6.037992734859289, 'gae_lambda': 0.8887924827914842, 'n_epochs': 6, 'clip_range_vf': 0.21837166760163168, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 13:54:15,665] Trial 138 pruned.
# [I 2024-02-18 13:58:35,463] Trial 139 pruned.
# [I 2024-02-18 14:01:51,788] Trial 140 pruned.
# [I 2024-02-18 14:06:15,644] Trial 141 pruned.
# [I 2024-02-18 14:10:28,968] Trial 142 pruned.
# [I 2024-02-18 14:14:49,094] Trial 143 pruned.
# [I 2024-02-18 14:19:26,191] Trial 144 pruned.
# [I 2024-02-18 14:23:31,444] Trial 145 pruned.
# [I 2024-02-18 14:28:29,288] Trial 146 pruned.
# [I 2024-02-18 14:33:37,871] Trial 147 pruned.
# [I 2024-02-18 14:37:15,474] Trial 148 pruned.
# [I 2024-02-18 15:03:47,283] Trial 149 finished with value: 39042.2 and parameters: {'lr': 1.274977854402515e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 5, 'gamma': 0.000996151328904857, 'ent_coef': 0.003880479112559257, 'clip_range': 0.3181147121826797, 'vf_coef': 0.5838103055332777, 'max_grad_norm': 2.2558943990152214, 'gae_lambda': 0.905032057765628, 'n_epochs': 5, 'clip_range_vf': 0.2512659562713763, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 15:08:45,764] Trial 150 pruned.
# [I 2024-02-18 15:13:48,663] Trial 151 pruned.
# [I 2024-02-18 15:19:09,430] Trial 152 pruned.
# [I 2024-02-18 15:24:19,728] Trial 153 pruned.
# [I 2024-02-18 15:29:03,412] Trial 154 pruned.
# [I 2024-02-18 15:35:05,848] Trial 155 pruned.
# [I 2024-02-18 15:38:54,567] Trial 156 pruned.
# [I 2024-02-18 15:43:46,879] Trial 157 pruned.
# [I 2024-02-18 15:48:26,906] Trial 158 pruned.
# [I 2024-02-18 15:53:05,026] Trial 159 pruned.
# [I 2024-02-18 16:38:46,067] Trial 160 finished with value: 38808.2 and parameters: {'lr': 0.011637348167660502, 'exponent_n_steps': 9, 'exponent_batch_size': 4, 'gamma': 0.0007136159792607967, 'ent_coef': 0.06232430135917191, 'clip_range': 0.13224473771929995, 'vf_coef': 0.7289656867658365, 'max_grad_norm': 0.47836202421246715, 'gae_lambda': 0.90760591011034, 'n_epochs': 5, 'clip_range_vf': 0.3195605004958567, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 16:44:18,527] Trial 161 pruned.
# [I 2024-02-18 17:05:37,171] Trial 162 finished with value: 38786.2 and parameters: {'lr': 0.06755087717466414, 'exponent_n_steps': 9, 'exponent_batch_size': 10, 'gamma': 0.00038316938773951453, 'ent_coef': 0.008913576301583476, 'clip_range': 0.14787939642721737, 'vf_coef': 0.7396151083402773, 'max_grad_norm': 0.10174244790073235, 'gae_lambda': 0.9275965433026112, 'n_epochs': 3, 'clip_range_vf': 0.2662533058788526, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 17:09:57,229] Trial 163 pruned.
# [I 2024-02-18 17:14:12,329] Trial 164 pruned.
# [I 2024-02-18 17:18:24,555] Trial 165 pruned.
# [I 2024-02-18 17:26:14,038] Trial 166 pruned.
# [I 2024-02-18 17:29:23,478] Trial 167 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 256`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 256
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=256 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 17:33:29,323] Trial 168 pruned.
# [I 2024-02-18 17:37:00,371] Trial 169 pruned.
# [I 2024-02-18 17:40:01,320] Trial 170 pruned.
# [I 2024-02-18 17:45:04,751] Trial 171 pruned.
# [I 2024-02-18 17:50:14,672] Trial 172 pruned.
# [I 2024-02-18 17:54:42,349] Trial 173 pruned.
# [I 2024-02-18 17:59:47,867] Trial 174 pruned.
# [I 2024-02-18 18:04:01,296] Trial 175 pruned.
# [I 2024-02-18 18:08:02,051] Trial 176 pruned.
# [I 2024-02-18 18:28:23,960] Trial 177 finished with value: 39052.6 and parameters: {'lr': 0.08466056111911933, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.029126196027892425, 'ent_coef': 0.08552049626895307, 'clip_range': 0.18339327870863406, 'vf_coef': 0.7495533739493303, 'max_grad_norm': 0.13637013894676728, 'gae_lambda': 0.8253259304530629, 'n_epochs': 5, 'clip_range_vf': 0.2358843578372415, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 18:44:28,695] Trial 178 finished with value: 39022.6 and parameters: {'lr': 0.0665877119257339, 'exponent_n_steps': 7, 'exponent_batch_size': 8, 'gamma': 0.030019050658005208, 'ent_coef': 0.06575420603636686, 'clip_range': 0.1640106313992346, 'vf_coef': 0.7430793555462926, 'max_grad_norm': 0.14229497871268165, 'gae_lambda': 0.8044204987872213, 'n_epochs': 5, 'clip_range_vf': 0.2510495150561418, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 18:48:36,015] Trial 179 pruned.
# [I 2024-02-18 18:52:30,519] Trial 180 pruned.
# [I 2024-02-18 18:56:30,277] Trial 181 pruned.
# [I 2024-02-18 19:00:31,631] Trial 182 pruned.
# [I 2024-02-18 19:05:27,694] Trial 183 pruned.
# [I 2024-02-18 19:10:12,081] Trial 184 pruned.
# [I 2024-02-18 19:39:47,030] Trial 185 finished with value: 39056.8 and parameters: {'lr': 0.009473262377828438, 'exponent_n_steps': 6, 'exponent_batch_size': 5, 'gamma': 0.0009093042222357344, 'ent_coef': 0.00017141322425268785, 'clip_range': 0.272677082090772, 'vf_coef': 0.5899163883102118, 'max_grad_norm': 0.35216917134738174, 'gae_lambda': 0.824022465532874, 'n_epochs': 6, 'clip_range_vf': 0.24642927623134853, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 19:43:31,055] Trial 186 pruned.
# [I 2024-02-18 19:50:32,536] Trial 187 pruned.
# [I 2024-02-18 19:57:09,259] Trial 188 pruned.
# [I 2024-02-18 20:01:32,627] Trial 189 pruned.
# [I 2024-02-18 20:06:38,005] Trial 190 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-18 20:14:46,566] Trial 191 pruned.
# [I 2024-02-18 20:19:50,281] Trial 192 pruned.
# [I 2024-02-18 20:26:31,151] Trial 193 pruned.
# [I 2024-02-18 20:32:56,325] Trial 194 pruned.
# [I 2024-02-18 20:37:23,540] Trial 195 pruned.
# [I 2024-02-18 21:06:30,930] Trial 196 finished with value: 39031.0 and parameters: {'lr': 0.052419792619117, 'exponent_n_steps': 6, 'exponent_batch_size': 8, 'gamma': 0.0009352810335727691, 'ent_coef': 0.0014097088270306694, 'clip_range': 0.1817863428729078, 'vf_coef': 0.6323600897003787, 'max_grad_norm': 0.19169561248781522, 'gae_lambda': 0.8955012095067794, 'n_epochs': 4, 'clip_range_vf': 0.23851417736425862, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 64 with value: 39101.4.
# [I 2024-02-18 21:12:14,348] Trial 197 pruned.
# [I 2024-02-18 21:16:08,467] Trial 198 pruned.
# [I 2024-02-18 21:21:09,362] Trial 199 pruned.
# Number of finished trials:  200
# Best trial:
#   Value: 39101.4
#   Params:
#     lr: 3.240817843698623e-05
#     exponent_n_steps: 7
#     exponent_batch_size: 8
#     gamma: 0.0008027656785736489
#     ent_coef: 0.0001899484641387907
#     clip_range: 0.13399956493573578
#     vf_coef: 0.6395307341097642
#     max_grad_norm: 1.1240988009356605
#     gae_lambda: 0.8993673780839393
#     n_epochs: 6
#     clip_range_vf: 0.2327530358366276
#     net_arch: tiny
#     activation_fn: relu
#   User attrs:
#     batch_size: 256
#     gamma: 0.9991972343214264
#     n_steps: 128
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 37
#      34 # Write report
#      35 study.trials_dataframe().to_csv("study_results_a2c_cartpole.csv")
# ---> 37 fig1 = plot_optimization_history(study)
#      38 fig2 = plot_param_importances(study)
#      40 fig1.show()
#
# File d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\optuna\visualization\_optimization_history.py:222, in plot_optimization_history(study, target, target_name, error_bar)
#     172 def plot_optimization_history(
#     173     study: Study | Sequence[Study],
#     174     *,
#    (...)
#     177     error_bar: bool = False,
#     178 ) -> "go.Figure":
#     179     """Plot optimization history of all trials in a study.
#     180
#     181     Example:
#    (...)
#     219         A :class:`plotly.graph_objs.Figure` object.
#     220     """
# --> 222     _imports.check()
#     224     info_list = _get_optimization_history_info_list(study, target, target_name, error_bar)
#     225     return _get_optimization_history_plot(info_list, target_name)
#
# File d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\optuna\_imports.py:89, in _DeferredImportExceptionContextManager.check(self)
#      87 if self._deferred is not None:
#      88     exc_value, message = self._deferred
# ---> 89     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.
