# %%
# Printa a versão do Python
import sys
print(f"Versão do Python: {sys.version}")
# Out:
# Versão do Python: 3.11.7 (tags/v3.11.7:fa7a6f2, Dec  4 2023, 19:24:49) [MSC v.1937 64 bit (AMD64)]

# %%
# Importa as bibliotecas
import os
import pickle

import numpy as np
import pandas as pd

import torch as th

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %matplotlib inline

print(f"Versão do PyTorch: {th.__version__}")
# Out:
# Versão do PyTorch: 2.1.2+cpu

# %%
from Enviroment.Settings import *
from Enviroment.Manager import Enviroment

# %%
from stable_baselines3 import PPO

# %%
from stable_baselines3.common.env_util import make_vec_env, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# Importando o Monitor
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

print(f"Versão do Gymnasium: {gym.__version__}")
# Out:
# Versão do Gymnasium: 0.29.1

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from optuna.visualization import plot_optimization_history, plot_param_importances

# %%
N_TRIALS = 500  # Maximum number of trials
N_JOBS = 1 # Number of jobs to run in parallel
N_STARTUP_TRIALS = 40  # Stop random sampling after N_STARTUP_TRIALS
N_EVALUATIONS = 6  # Number of evaluations during the training
N_TIMESTEPS = int(6e5)  # Training budget
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_ENVS = 5
N_EVAL_EPISODES = 10
TIMEOUT = int(60 * 60 * 24 * 5)  # 5 dias 

enviroment_type = {
    "Observation": "ODD-one-hot",
    "Action": "RSA-SAR",
    "Reward": "RL-defaut",
    "StopCond": "40kReqs",
    "StartCond": "Empty"
}

env = Enviroment(
    network_load=300,
    k_routes=3,
    number_of_slots=128,
    enviroment_type=enviroment_type,
    data_folder="Train_PPO_Optuna_v2",
)

env_eval = Enviroment(
    network_load=300,
    k_routes=3,
    number_of_slots=128,
    enviroment_type=enviroment_type,
    data_folder="Train_PPO_Optuna_v2_e",
)

#env = Monitor(DummyVecEnv(env))

DEFAULT_HYPERPARAMS = {
    "policy": "MlpPolicy",
    "env": env,
}

# %%
from typing import Any, Dict
import torch
import torch.nn as nn

def sample_PPO_params(trial: optuna.Trial) -> Dict[str, Any]:
    """
    Sampler for PPO hyperparameters.

    :param trial: Optuna trial object
    :return: The sampled hyperparameters for the given trial.
    """
    learning_rate = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    # 16, 32, ... 16384
    n_steps = 2 ** trial.suggest_int("exponent_n_steps", 4, 14)
    batch_size = 2 ** trial.suggest_int("exponent_batch_size", 4, 11)
    # Discount factor between 0.9 and 0.9999
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    ent_coef = trial.suggest_float('ent_coef', 1e-10, 0.1, log=True)
    clip_range = trial.suggest_float('clip_range', 0.1, 0.4)
    vf_coef = trial.suggest_float('vf_coef', 0.25, 0.75)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.01, 10.0, log=True)
    gae_lambda = trial.suggest_float("gae_lambda", 0.8, 0.99, log=True)
    n_epochs = trial.suggest_int("n_epochs", 2, 10)
    clip_range_vf = trial.suggest_float("clip_range_vf", 0.1, 0.4)

    net_arch_c = trial.suggest_categorical("net_arch", ["tiny", "small", "big", "huge"])
    activation_fn = trial.suggest_categorical("activation_fn", ["tanh", "LeakyReLU"])

    # Display true values
    trial.set_user_attr("gamma", gamma)
    trial.set_user_attr("n_steps", n_steps)
    trial.set_user_attr("batch_size", batch_size)

    if net_arch_c == "tiny":
        net_arch = {"pi": [128], "vf": [128]}
    elif net_arch_c == "small":
        net_arch = {"pi": [256, 256], "vf": [256, 256]}
    elif net_arch_c == "big":
        net_arch = {"pi": [512, 256], "vf": [512, 128]}
    elif net_arch_c == "huge":
        net_arch = {"pi": [1024, 512, 256], "vf": [1024, 512, 128]}
        
    activation_fn = {"tanh": nn.Tanh, "LeakyReLU": nn.LeakyReLU}[activation_fn]

    return {
        "learning_rate": learning_rate,
        "n_steps": n_steps,
        "batch_size": batch_size,
        "gamma": gamma,
        "ent_coef": ent_coef,
        "clip_range": clip_range,
        "vf_coef": vf_coef,
        "max_grad_norm": max_grad_norm,
        "gae_lambda": gae_lambda,
        "n_epochs": n_epochs,
        "clip_range_vf": clip_range_vf,
        "policy_kwargs": {
            "net_arch": net_arch,
            "activation_fn": activation_fn,
        },
    }

# %%
from stable_baselines3.common.callbacks import EvalCallback

class TrialEvalCallback(EvalCallback):
    """
    Callback used for evaluating and reporting a trial.
    
    :param eval_env: Evaluation environement
    :param trial: Optuna trial object
    :param n_eval_episodes: Number of evaluation episodes
    :param eval_freq:   Evaluate the agent every ``eval_freq`` call of the callback.
    :param deterministic: Whether the evaluation should
        use a stochastic or deterministic policy.
    :param verbose:
    """

    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 80_000,
        deterministic: bool = True,
        verbose: int = 0,
    ):

        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            # Evaluate policy (done in the parent class)
            super()._on_step()
            self.eval_idx += 1
            # Send report to Optuna
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %%
def objective(trial: optuna.Trial) -> float:
    """
    Objective function using by Optuna to evaluate
    one configuration (i.e., one set of hyperparameters).

    Given a trial object, it will sample hyperparameters,
    evaluate it and report the result (mean episodic reward after training)

    :param trial: Optuna trial object
    :return: Mean episodic reward after training
    """

    kwargs = DEFAULT_HYPERPARAMS.copy()
    ### YOUR CODE HERE
    # TODO: 
    # 1. Sample hyperparameters and update the default keyword arguments: `kwargs.update(other_params)`
    # 2. Create the evaluation envs
    # 3. Create the `TrialEvalCallback`

    # 1. Sample hyperparameters and update the keyword arguments
    kwargs.update(sample_PPO_params(trial))

    # Create the RL model
    model = PPO(**kwargs)

    # 2. Create envs used for evaluation using `make_vec_env`, `ENV_ID` and `N_EVAL_ENVS`
    #eval_envs = make_vec_env(env, N_EVAL_ENVS)

    # 3. Create the `TrialEvalCallback` callback defined above that will periodically evaluate
    # and report the performance using `N_EVAL_EPISODES` every `EVAL_FREQ`
    # TrialEvalCallback signature:
    # TrialEvalCallback(eval_env, trial, n_eval_episodes, eval_freq, deterministic, verbose)
    eval_callback = TrialEvalCallback(env_eval, trial, N_EVAL_EPISODES, EVAL_FREQ, True)

    ### END OF YOUR CODE

    nan_encountered = False
    try:
        # Train the model
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN
        print(e)
        nan_encountered = True
    finally:
        # Free memory
        model.env.close()
        #eval_envs.close()

    # Tell the optimizer that the trial failed
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward

# %%
import torch as th

# Set pytorch num threads to 1 for faster training
th.set_num_threads(1)
# Select the sampler, can be random, TPESampler, CMAES, ...
sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
# Do not prune before 1/3 of the max budget is used
pruner = MedianPruner(
    n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3
)
# Create the study and start the hyperparameter optimization
study = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize", study_name="ODD_RSA_RSA_v5", storage="sqlite:///ODD_RSA_RSA.db")

try:
    study.optimize(objective, n_trials=N_TRIALS, n_jobs=N_JOBS, timeout=TIMEOUT)
except KeyboardInterrupt:
    pass

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")

print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

print("  User attrs:")
for key, value in trial.user_attrs.items():
    print(f"    {key}: {value}")

# Write report
study.trials_dataframe().to_csv("study_results_a2c_cartpole.csv")

fig1 = plot_optimization_history(study)
fig2 = plot_param_importances(study)

fig1.show()
fig2.show()
# Out:
# [I 2024-02-21 17:44:47,487] A new study created in RDB with name: ODD_RSA_RSA_v5
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2024-02-21 19:28:26,238] Trial 0 finished with value: 38952.2 and parameters: {'lr': 2.6759521992847878e-05, 'exponent_n_steps': 5, 'exponent_batch_size': 10, 'gamma': 0.00014820339123240616, 'ent_coef': 0.00014529563103765725, 'clip_range': 0.12541397183747077, 'vf_coef': 0.38547914570085823, 'max_grad_norm': 0.04992311591926643, 'gae_lambda': 0.8805286591550723, 'n_epochs': 9, 'clip_range_vf': 0.3269632381040989, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 0 with value: 38952.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-21 21:28:12,752] Trial 1 finished with value: 38927.4 and parameters: {'lr': 0.0002607407076119749, 'exponent_n_steps': 4, 'exponent_batch_size': 10, 'gamma': 0.0010992491023240024, 'ent_coef': 2.039937104917831e-08, 'clip_range': 0.33970068445557355, 'vf_coef': 0.6907750851610777, 'max_grad_norm': 0.03382520843066487, 'gae_lambda': 0.8266858397829849, 'n_epochs': 5, 'clip_range_vf': 0.26356837369375, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 0 with value: 38952.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 1024`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 1024
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1024 and n_envs=1)
#   warnings.warn(
# [I 2024-02-21 21:49:19,076] Trial 2 finished with value: 38915.0 and parameters: {'lr': 0.0024889139104334063, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.001353245402128642, 'ent_coef': 0.058778549782923024, 'clip_range': 0.12912858877569208, 'vf_coef': 0.4132699202450489, 'max_grad_norm': 1.503201637071327, 'gae_lambda': 0.9848006280450841, 'n_epochs': 2, 'clip_range_vf': 0.2822651142731137, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 0 with value: 38952.2.
# [I 2024-02-21 22:16:45,162] Trial 3 finished with value: 39068.0 and parameters: {'lr': 2.6014058367672148e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.03729144306202928, 'ent_coef': 0.04496925870880193, 'clip_range': 0.18155719551203775, 'vf_coef': 0.6959840519748636, 'max_grad_norm': 3.6384507597609104, 'gae_lambda': 0.9076104097818123, 'n_epochs': 3, 'clip_range_vf': 0.29257423009277783, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 3 with value: 39068.0.
# [I 2024-02-21 23:09:10,544] Trial 4 finished with value: 39058.6 and parameters: {'lr': 3.256696859122998e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 7, 'gamma': 0.09469117006238875, 'ent_coef': 5.326368677309296e-09, 'clip_range': 0.3002857349179733, 'vf_coef': 0.2858273406962581, 'max_grad_norm': 1.1262205614775795, 'gae_lambda': 0.9085802338011197, 'n_epochs': 6, 'clip_range_vf': 0.12412006339514249, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 3 with value: 39068.0.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-21 23:35:38,682] Trial 5 finished with value: 39121.2 and parameters: {'lr': 0.00016277674120359568, 'exponent_n_steps': 6, 'exponent_batch_size': 11, 'gamma': 0.0018114764166189264, 'ent_coef': 1.443231039975174e-10, 'clip_range': 0.24459960882260687, 'vf_coef': 0.5083039998017436, 'max_grad_norm': 0.2356064216145423, 'gae_lambda': 0.8399785711409049, 'n_epochs': 6, 'clip_range_vf': 0.33249570021054453, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 00:46:48,688] Trial 6 finished with value: 38890.2 and parameters: {'lr': 1.7388802270214875e-05, 'exponent_n_steps': 7, 'exponent_batch_size': 5, 'gamma': 0.0046900971672785485, 'ent_coef': 1.1815472248412263e-08, 'clip_range': 0.2572826058662874, 'vf_coef': 0.52704142477495, 'max_grad_norm': 0.2092159631484889, 'gae_lambda': 0.9323726982096947, 'n_epochs': 7, 'clip_range_vf': 0.1952083536183214, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 01:04:42,113] Trial 7 finished with value: 39024.6 and parameters: {'lr': 0.0040968127498383, 'exponent_n_steps': 13, 'exponent_batch_size': 11, 'gamma': 0.0125214625805769, 'ent_coef': 3.216230991723824e-08, 'clip_range': 0.17394868384021714, 'vf_coef': 0.3892918692624616, 'max_grad_norm': 0.11735967073703937, 'gae_lambda': 0.9772524310882875, 'n_epochs': 5, 'clip_range_vf': 0.1379479469623066, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 01:42:43,371] Trial 8 finished with value: 38896.4 and parameters: {'lr': 0.005925911780344943, 'exponent_n_steps': 11, 'exponent_batch_size': 9, 'gamma': 0.00029445169912519165, 'ent_coef': 0.00042628298074185757, 'clip_range': 0.17146687923023662, 'vf_coef': 0.7399084044620907, 'max_grad_norm': 0.021687266697074773, 'gae_lambda': 0.9468691659242383, 'n_epochs': 5, 'clip_range_vf': 0.19998684594778576, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 02:11:39,335] Trial 9 finished with value: 38831.6 and parameters: {'lr': 0.008967776099093947, 'exponent_n_steps': 9, 'exponent_batch_size': 4, 'gamma': 0.00021330099883625961, 'ent_coef': 0.015214917036210123, 'clip_range': 0.18491071448252433, 'vf_coef': 0.35548752889700014, 'max_grad_norm': 0.03297517210360658, 'gae_lambda': 0.9770821889667267, 'n_epochs': 3, 'clip_range_vf': 0.26127816227862444, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 02:32:43,325] Trial 10 finished with value: 39055.2 and parameters: {'lr': 0.000710326502224665, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.0036472282761475182, 'ent_coef': 2.3007012604539915e-05, 'clip_range': 0.15896066585489316, 'vf_coef': 0.6050381063554873, 'max_grad_norm': 0.6286599552092347, 'gae_lambda': 0.9558053190502697, 'n_epochs': 3, 'clip_range_vf': 0.18378752954151234, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 02:52:58,487] Trial 11 finished with value: 38912.0 and parameters: {'lr': 3.497784166975662e-05, 'exponent_n_steps': 13, 'exponent_batch_size': 9, 'gamma': 0.002650902288635343, 'ent_coef': 3.866147618735105e-05, 'clip_range': 0.22854546971833364, 'vf_coef': 0.35260331444654835, 'max_grad_norm': 1.1348353218758802, 'gae_lambda': 0.8735908151238085, 'n_epochs': 3, 'clip_range_vf': 0.2240679638257314, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 03:40:00,073] Trial 12 finished with value: 38978.2 and parameters: {'lr': 0.00710239791451596, 'exponent_n_steps': 12, 'exponent_batch_size': 11, 'gamma': 0.005893632183944438, 'ent_coef': 0.012734411280543268, 'clip_range': 0.3921252832943931, 'vf_coef': 0.3295666832019114, 'max_grad_norm': 3.1999125247274516, 'gae_lambda': 0.8484185733504229, 'n_epochs': 9, 'clip_range_vf': 0.3710071942245635, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 04:01:28,149] Trial 13 finished with value: 38872.8 and parameters: {'lr': 0.001226719696256471, 'exponent_n_steps': 9, 'exponent_batch_size': 9, 'gamma': 0.016126952404275908, 'ent_coef': 0.0014679307652727275, 'clip_range': 0.36299769105520185, 'vf_coef': 0.3611707883406677, 'max_grad_norm': 0.05943616162899879, 'gae_lambda': 0.9105834527256998, 'n_epochs': 6, 'clip_range_vf': 0.16097763334028126, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 512, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 04:23:30,658] Trial 14 finished with value: 38853.0 and parameters: {'lr': 3.502782591570351e-05, 'exponent_n_steps': 5, 'exponent_batch_size': 9, 'gamma': 0.007608753868820104, 'ent_coef': 0.04404208880341705, 'clip_range': 0.10607789579378966, 'vf_coef': 0.4166953877987941, 'max_grad_norm': 3.983981056635025, 'gae_lambda': 0.9379631528749368, 'n_epochs': 7, 'clip_range_vf': 0.3792472312557509, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 04:52:42,223] Trial 15 finished with value: 39012.2 and parameters: {'lr': 0.0019055457233442296, 'exponent_n_steps': 4, 'exponent_batch_size': 6, 'gamma': 0.0040427382956885315, 'ent_coef': 4.84485800666471e-06, 'clip_range': 0.35285188263991885, 'vf_coef': 0.5103666994891168, 'max_grad_norm': 0.014402982909110077, 'gae_lambda': 0.8658378294859362, 'n_epochs': 9, 'clip_range_vf': 0.3746157048735659, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 05:13:16,714] Trial 16 finished with value: 39031.2 and parameters: {'lr': 0.01788073153019266, 'exponent_n_steps': 5, 'exponent_batch_size': 4, 'gamma': 0.005005822680816385, 'ent_coef': 0.01570667790846225, 'clip_range': 0.3494799603502614, 'vf_coef': 0.3261054214715449, 'max_grad_norm': 0.04197836071390738, 'gae_lambda': 0.8162507834854045, 'n_epochs': 2, 'clip_range_vf': 0.16708157921839314, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 07:18:40,220] Trial 17 finished with value: 38915.0 and parameters: {'lr': 0.0001180727962456429, 'exponent_n_steps': 9, 'exponent_batch_size': 4, 'gamma': 0.0003328429499321118, 'ent_coef': 0.016143331519995745, 'clip_range': 0.10123335841210472, 'vf_coef': 0.25047192923621037, 'max_grad_norm': 5.692957579791815, 'gae_lambda': 0.8325457944122919, 'n_epochs': 9, 'clip_range_vf': 0.26216509865310633, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 07:46:28,287] Trial 18 finished with value: 38919.6 and parameters: {'lr': 0.0359020321263471, 'exponent_n_steps': 4, 'exponent_batch_size': 11, 'gamma': 0.00028315581946134177, 'ent_coef': 3.310355535310824e-05, 'clip_range': 0.2631651579568431, 'vf_coef': 0.5749016680090061, 'max_grad_norm': 0.024034432952982417, 'gae_lambda': 0.8826554566740303, 'n_epochs': 2, 'clip_range_vf': 0.2821624260223937, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 08:07:27,558] Trial 19 finished with value: 38872.6 and parameters: {'lr': 0.004507385617540462, 'exponent_n_steps': 8, 'exponent_batch_size': 7, 'gamma': 0.05106835316675557, 'ent_coef': 6.953169031699149e-09, 'clip_range': 0.32003606175969856, 'vf_coef': 0.3540671816065902, 'max_grad_norm': 0.3194694100350947, 'gae_lambda': 0.9308508648379367, 'n_epochs': 3, 'clip_range_vf': 0.24403912532799632, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 08:36:10,279] Trial 20 finished with value: 39040.6 and parameters: {'lr': 6.202924124963375e-05, 'exponent_n_steps': 14, 'exponent_batch_size': 4, 'gamma': 0.004440313928959853, 'ent_coef': 1.2159512797373988e-06, 'clip_range': 0.22743721808326256, 'vf_coef': 0.5224793412176536, 'max_grad_norm': 0.24793720324283844, 'gae_lambda': 0.8859254661991892, 'n_epochs': 9, 'clip_range_vf': 0.2422337462427758, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 08:59:26,306] Trial 21 finished with value: 38817.0 and parameters: {'lr': 0.0319744237997307, 'exponent_n_steps': 6, 'exponent_batch_size': 11, 'gamma': 0.00010209049503866674, 'ent_coef': 0.04364333702948113, 'clip_range': 0.28488832489418403, 'vf_coef': 0.3200022686973724, 'max_grad_norm': 5.396495099764387, 'gae_lambda': 0.8304687017446257, 'n_epochs': 3, 'clip_range_vf': 0.11775791420251674, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 09:17:57,190] Trial 22 finished with value: 38880.2 and parameters: {'lr': 0.06908432532992803, 'exponent_n_steps': 7, 'exponent_batch_size': 11, 'gamma': 0.03088508054729331, 'ent_coef': 0.004155615622608637, 'clip_range': 0.12165487618667373, 'vf_coef': 0.6101420750120061, 'max_grad_norm': 0.021530280608489855, 'gae_lambda': 0.8990823501588147, 'n_epochs': 7, 'clip_range_vf': 0.20116242405737483, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 09:39:40,601] Trial 23 finished with value: 39009.2 and parameters: {'lr': 0.09141352789450076, 'exponent_n_steps': 10, 'exponent_batch_size': 4, 'gamma': 0.000799451876050322, 'ent_coef': 3.4417905908338612e-09, 'clip_range': 0.33390974405285, 'vf_coef': 0.516909711804931, 'max_grad_norm': 0.12558865163802596, 'gae_lambda': 0.9381571908578651, 'n_epochs': 2, 'clip_range_vf': 0.1505107238234127, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 11:24:26,864] Trial 24 finished with value: 38819.4 and parameters: {'lr': 6.0372758924358325e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 4, 'gamma': 0.000893344800661044, 'ent_coef': 1.3828333829302073e-10, 'clip_range': 0.17545880183628004, 'vf_coef': 0.5608355559345375, 'max_grad_norm': 2.734344534784902, 'gae_lambda': 0.8547142878288283, 'n_epochs': 6, 'clip_range_vf': 0.15341842166291567, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 11:54:39,137] Trial 25 finished with value: 38853.0 and parameters: {'lr': 0.020463576892978563, 'exponent_n_steps': 7, 'exponent_batch_size': 6, 'gamma': 0.00030848753233918134, 'ent_coef': 0.07037624399811238, 'clip_range': 0.3308320266529031, 'vf_coef': 0.48836189928001766, 'max_grad_norm': 1.8172327871582141, 'gae_lambda': 0.9732786324359481, 'n_epochs': 9, 'clip_range_vf': 0.396936080880562, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 12:14:34,282] Trial 26 finished with value: 38834.8 and parameters: {'lr': 0.00011256955637766476, 'exponent_n_steps': 14, 'exponent_batch_size': 9, 'gamma': 0.08368335523142269, 'ent_coef': 1.2991752115408176e-08, 'clip_range': 0.3254463865403435, 'vf_coef': 0.462284677542102, 'max_grad_norm': 0.06380379755945081, 'gae_lambda': 0.8058622609385294, 'n_epochs': 9, 'clip_range_vf': 0.38664866356030225, 'net_arch': 'tiny', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 13:07:45,711] Trial 27 finished with value: 38826.2 and parameters: {'lr': 0.08501744907661779, 'exponent_n_steps': 12, 'exponent_batch_size': 5, 'gamma': 0.0005346631726381922, 'ent_coef': 1.017953099924256e-09, 'clip_range': 0.2987142780787431, 'vf_coef': 0.6400652115906246, 'max_grad_norm': 0.2022422375920821, 'gae_lambda': 0.9243558158056043, 'n_epochs': 8, 'clip_range_vf': 0.2325980355737191, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 13:37:52,484] Trial 28 finished with value: 38825.4 and parameters: {'lr': 0.0012650174001520363, 'exponent_n_steps': 14, 'exponent_batch_size': 4, 'gamma': 0.007312379893759819, 'ent_coef': 0.00030903681640062343, 'clip_range': 0.32141882416714085, 'vf_coef': 0.5630720682704101, 'max_grad_norm': 0.9908921726492295, 'gae_lambda': 0.9819286757143867, 'n_epochs': 8, 'clip_range_vf': 0.12385916588213437, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 14:31:04,583] Trial 29 finished with value: 38896.4 and parameters: {'lr': 0.007409059711734935, 'exponent_n_steps': 9, 'exponent_batch_size': 4, 'gamma': 0.00018998347419926553, 'ent_coef': 0.005977365026507361, 'clip_range': 0.3323387605009236, 'vf_coef': 0.4833295930926706, 'max_grad_norm': 3.1859968592197023, 'gae_lambda': 0.835612080807949, 'n_epochs': 8, 'clip_range_vf': 0.3434128818723417, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 14:59:49,239] Trial 30 finished with value: 38878.6 and parameters: {'lr': 0.00014357719893910291, 'exponent_n_steps': 12, 'exponent_batch_size': 7, 'gamma': 0.0016978961490980793, 'ent_coef': 1.0222140094819396e-10, 'clip_range': 0.16689625912317269, 'vf_coef': 0.4608879315862986, 'max_grad_norm': 0.15457380451293734, 'gae_lambda': 0.985852410266473, 'n_epochs': 8, 'clip_range_vf': 0.10955284517926055, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 15:33:39,967] Trial 31 finished with value: 38850.8 and parameters: {'lr': 0.000323312277772928, 'exponent_n_steps': 11, 'exponent_batch_size': 5, 'gamma': 0.0018041877651179294, 'ent_coef': 0.0008372627427974333, 'clip_range': 0.31021248239763083, 'vf_coef': 0.27756684678830673, 'max_grad_norm': 0.025826442392757797, 'gae_lambda': 0.8638628200885642, 'n_epochs': 5, 'clip_range_vf': 0.20225113955876234, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 16:10:48,403] Trial 32 finished with value: 38950.8 and parameters: {'lr': 0.0005870027010637138, 'exponent_n_steps': 12, 'exponent_batch_size': 4, 'gamma': 0.00018014423717838956, 'ent_coef': 1.0658958320089933e-06, 'clip_range': 0.34241014387865587, 'vf_coef': 0.7115195987200436, 'max_grad_norm': 6.58692526266417, 'gae_lambda': 0.8614087186510644, 'n_epochs': 5, 'clip_range_vf': 0.11973359403345171, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 16:59:27,753] Trial 33 finished with value: 38957.6 and parameters: {'lr': 1.8490277534452625e-05, 'exponent_n_steps': 8, 'exponent_batch_size': 4, 'gamma': 0.011087898682237822, 'ent_coef': 0.018252886960838426, 'clip_range': 0.30950545844548183, 'vf_coef': 0.28757338205019745, 'max_grad_norm': 0.08390525948970277, 'gae_lambda': 0.8194101193695221, 'n_epochs': 7, 'clip_range_vf': 0.29820119541485973, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 17:28:10,290] Trial 34 finished with value: 38941.4 and parameters: {'lr': 0.001824765726966258, 'exponent_n_steps': 11, 'exponent_batch_size': 4, 'gamma': 0.02453177062382273, 'ent_coef': 3.095037696068605e-08, 'clip_range': 0.18367633232985048, 'vf_coef': 0.34781527591237826, 'max_grad_norm': 0.7012034453596504, 'gae_lambda': 0.837025815924691, 'n_epochs': 7, 'clip_range_vf': 0.23830665315251057, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 18:24:44,341] Trial 35 finished with value: 38786.8 and parameters: {'lr': 7.399406352319401e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.06358904304465275, 'ent_coef': 7.592402590496989e-10, 'clip_range': 0.2407537622583608, 'vf_coef': 0.5663566625186321, 'max_grad_norm': 1.3530298039858382, 'gae_lambda': 0.807034815722868, 'n_epochs': 10, 'clip_range_vf': 0.1992365817379208, 'net_arch': 'huge', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 256`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 256
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=256 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 18:42:07,774] Trial 36 finished with value: 38876.6 and parameters: {'lr': 0.001435232745171708, 'exponent_n_steps': 8, 'exponent_batch_size': 10, 'gamma': 0.00010141873832392294, 'ent_coef': 0.00033134906971416824, 'clip_range': 0.14555989128726143, 'vf_coef': 0.40723183663161877, 'max_grad_norm': 5.47023750425312, 'gae_lambda': 0.8180336534313472, 'n_epochs': 4, 'clip_range_vf': 0.2116226305185034, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 19:00:38,194] Trial 37 finished with value: 39004.8 and parameters: {'lr': 0.004476065098488633, 'exponent_n_steps': 13, 'exponent_batch_size': 6, 'gamma': 0.0001734739394717135, 'ent_coef': 0.0013828667110140367, 'clip_range': 0.29250508674364584, 'vf_coef': 0.6767891938343091, 'max_grad_norm': 0.5691096306561929, 'gae_lambda': 0.927352280128241, 'n_epochs': 4, 'clip_range_vf': 0.19290600760443147, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 19:29:04,306] Trial 38 finished with value: 38812.8 and parameters: {'lr': 0.01471196676083207, 'exponent_n_steps': 8, 'exponent_batch_size': 6, 'gamma': 0.0007348655600270353, 'ent_coef': 2.5838649743987684e-05, 'clip_range': 0.24947730111322244, 'vf_coef': 0.5983565498209714, 'max_grad_norm': 0.11067647016016541, 'gae_lambda': 0.868777992703857, 'n_epochs': 10, 'clip_range_vf': 0.3864570871018864, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 20:15:52,111] Trial 39 finished with value: 38997.0 and parameters: {'lr': 0.00021514147255070743, 'exponent_n_steps': 5, 'exponent_batch_size': 6, 'gamma': 0.002671371160341128, 'ent_coef': 4.0883713578656537e-07, 'clip_range': 0.18791775162401025, 'vf_coef': 0.31865880988152834, 'max_grad_norm': 0.12990610529484212, 'gae_lambda': 0.8274501859424355, 'n_epochs': 3, 'clip_range_vf': 0.17609947589955743, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 20:38:09,505] Trial 40 finished with value: 39025.4 and parameters: {'lr': 1.2201659321766092e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.09798592530624957, 'ent_coef': 1.1411115033177065e-07, 'clip_range': 0.20767134313320232, 'vf_coef': 0.6546580171280305, 'max_grad_norm': 0.44495721089619233, 'gae_lambda': 0.9579583906833113, 'n_epochs': 4, 'clip_range_vf': 0.3248515335096919, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 21:01:13,101] Trial 41 finished with value: 38860.8 and parameters: {'lr': 0.00047833151392306835, 'exponent_n_steps': 10, 'exponent_batch_size': 8, 'gamma': 0.03424030357474288, 'ent_coef': 6.759741150445607e-06, 'clip_range': 0.21020938395304795, 'vf_coef': 0.7235844899539937, 'max_grad_norm': 0.2946192339122472, 'gae_lambda': 0.9005237271708519, 'n_epochs': 6, 'clip_range_vf': 0.3158173935864718, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 21:26:25,848] Trial 42 finished with value: 38913.2 and parameters: {'lr': 5.1047420247151695e-05, 'exponent_n_steps': 14, 'exponent_batch_size': 8, 'gamma': 0.003649907175343899, 'ent_coef': 1.0308522377077193e-07, 'clip_range': 0.2687595233168581, 'vf_coef': 0.4415809640028583, 'max_grad_norm': 8.948535228213238, 'gae_lambda': 0.8867691342000393, 'n_epochs': 6, 'clip_range_vf': 0.3504787806211835, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 21:50:11,713] Trial 43 finished with value: 38878.8 and parameters: {'lr': 2.0050755070906678e-05, 'exponent_n_steps': 13, 'exponent_batch_size': 10, 'gamma': 0.00127508387234173, 'ent_coef': 4.167074425377478e-10, 'clip_range': 0.2063213002856453, 'vf_coef': 0.5378209613540788, 'max_grad_norm': 0.7791535945498173, 'gae_lambda': 0.9155074878821566, 'n_epochs': 4, 'clip_range_vf': 0.2951674525694925, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 22:36:11,663] Trial 44 finished with value: 39009.4 and parameters: {'lr': 4.335205393865445e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.01731614954875971, 'ent_coef': 2.8105895011181796e-09, 'clip_range': 0.1463153760251697, 'vf_coef': 0.6086231432791211, 'max_grad_norm': 2.100982201208405, 'gae_lambda': 0.9588290447182324, 'n_epochs': 5, 'clip_range_vf': 0.3487574036035986, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-22 22:59:49,546] Trial 45 finished with value: 39026.4 and parameters: {'lr': 2.7417646956308562e-05, 'exponent_n_steps': 13, 'exponent_batch_size': 10, 'gamma': 0.0020047701102370347, 'ent_coef': 0.00012044681685078548, 'clip_range': 0.2343267578702864, 'vf_coef': 0.5433520450063485, 'max_grad_norm': 0.3765942787893358, 'gae_lambda': 0.8967518455545247, 'n_epochs': 4, 'clip_range_vf': 0.2730690356200592, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-22 23:49:44,599] Trial 46 finished with value: 39053.4 and parameters: {'lr': 1.0235256371956866e-05, 'exponent_n_steps': 6, 'exponent_batch_size': 8, 'gamma': 0.0467644861559695, 'ent_coef': 1.3504675144808048e-06, 'clip_range': 0.22215919157903236, 'vf_coef': 0.641671271956971, 'max_grad_norm': 0.19930768384112638, 'gae_lambda': 0.9122708644479706, 'n_epochs': 5, 'clip_range_vf': 0.299253248017648, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 00:05:48,391] Trial 47 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 128, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 01:02:18,210] Trial 48 finished with value: 39024.8 and parameters: {'lr': 0.0006970565462884064, 'exponent_n_steps': 6, 'exponent_batch_size': 7, 'gamma': 0.07235008270336185, 'ent_coef': 1.1343379703523333e-07, 'clip_range': 0.2222078628628565, 'vf_coef': 0.6412647375786975, 'max_grad_norm': 0.9054410790001001, 'gae_lambda': 0.8778699724273263, 'n_epochs': 6, 'clip_range_vf': 0.3352736667123897, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 512, but because the `RolloutBuffer` is of size `n_steps * n_envs = 64`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 64
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=64 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 01:41:59,679] Trial 49 finished with value: 38980.0 and parameters: {'lr': 2.91824672819564e-05, 'exponent_n_steps': 6, 'exponent_batch_size': 9, 'gamma': 0.05068010791967821, 'ent_coef': 8.592939924367856e-05, 'clip_range': 0.19808273918211589, 'vf_coef': 0.6845800288390648, 'max_grad_norm': 0.21629008451570159, 'gae_lambda': 0.9146490952829502, 'n_epochs': 3, 'clip_range_vf': 0.2808929146902144, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 512`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 512
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=512 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 02:13:30,844] Trial 50 finished with value: 39061.2 and parameters: {'lr': 1.4500737569715429e-05, 'exponent_n_steps': 9, 'exponent_batch_size': 11, 'gamma': 0.01982757210584687, 'ent_coef': 1.8647500098167693e-06, 'clip_range': 0.26933770658702044, 'vf_coef': 0.661463021597103, 'max_grad_norm': 1.5924477755037623, 'gae_lambda': 0.9463671158270562, 'n_epochs': 2, 'clip_range_vf': 0.25441965051794124, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 02:23:43,662] Trial 51 pruned.
# [I 2024-02-23 02:34:31,912] Trial 52 pruned.
# [I 2024-02-23 04:08:29,323] Trial 53 finished with value: 39071.0 and parameters: {'lr': 9.379262046813566e-05, 'exponent_n_steps': 4, 'exponent_batch_size': 11, 'gamma': 0.014869634178351207, 'ent_coef': 2.2618908703116506e-10, 'clip_range': 0.25809902946322927, 'vf_coef': 0.6453678242755811, 'max_grad_norm': 0.654640276688658, 'gae_lambda': 0.9442639282268709, 'n_epochs': 6, 'clip_range_vf': 0.3589868549689323, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 05:43:13,177] Trial 54 finished with value: 39038.6 and parameters: {'lr': 8.561241416800141e-05, 'exponent_n_steps': 4, 'exponent_batch_size': 11, 'gamma': 0.011965104950906767, 'ent_coef': 2.354112573596112e-10, 'clip_range': 0.260126280190721, 'vf_coef': 0.5907444001088686, 'max_grad_norm': 0.6600946029396799, 'gae_lambda': 0.9365483510376202, 'n_epochs': 6, 'clip_range_vf': 0.3627255623567695, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 06:29:06,406] Trial 55 finished with value: 38964.6 and parameters: {'lr': 0.00022863887338055142, 'exponent_n_steps': 5, 'exponent_batch_size': 10, 'gamma': 0.01650605200445101, 'ent_coef': 1.829704480204844e-09, 'clip_range': 0.2780716926748793, 'vf_coef': 0.6163376192591761, 'max_grad_norm': 1.7000909456856919, 'gae_lambda': 0.950020684703081, 'n_epochs': 3, 'clip_range_vf': 0.31171576628539316, 'net_arch': 'huge', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 06:51:04,569] Trial 56 finished with value: 39070.4 and parameters: {'lr': 3.980061330290341e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 11, 'gamma': 0.008897396459162646, 'ent_coef': 6.635498871422117e-09, 'clip_range': 0.1187025546163622, 'vf_coef': 0.6209123474530793, 'max_grad_norm': 4.306037382427127, 'gae_lambda': 0.9424234065476259, 'n_epochs': 2, 'clip_range_vf': 0.21957049047589128, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 07:12:09,238] Trial 57 finished with value: 38996.0 and parameters: {'lr': 3.792440116233667e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 11, 'gamma': 0.00894548852213621, 'ent_coef': 6.838285203133074e-09, 'clip_range': 0.3739627284674678, 'vf_coef': 0.6235778927264685, 'max_grad_norm': 4.045278008581911, 'gae_lambda': 0.9426591100725211, 'n_epochs': 2, 'clip_range_vf': 0.22335320629535188, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 07:39:48,632] Trial 58 finished with value: 38854.8 and parameters: {'lr': 2.379238232511495e-05, 'exponent_n_steps': 4, 'exponent_batch_size': 11, 'gamma': 0.005880490814218004, 'ent_coef': 3.897468996088867e-10, 'clip_range': 0.11887601785258217, 'vf_coef': 0.7332499062315785, 'max_grad_norm': 4.0336424474762085, 'gae_lambda': 0.9238728516192799, 'n_epochs': 2, 'clip_range_vf': 0.3627217357271434, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 512`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 512
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=512 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 07:54:54,267] Trial 59 pruned.
# [I 2024-02-23 08:16:00,067] Trial 60 finished with value: 39092.8 and parameters: {'lr': 9.199851972791604e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.01815473591949103, 'ent_coef': 2.891226584830599e-07, 'clip_range': 0.2975702639867564, 'vf_coef': 0.381087502392886, 'max_grad_norm': 1.1505885262957165, 'gae_lambda': 0.9026411125400969, 'n_epochs': 3, 'clip_range_vf': 0.3274168992985197, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 08:37:19,759] Trial 61 finished with value: 39121.0 and parameters: {'lr': 0.00010241036716356834, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.01920749418741408, 'ent_coef': 2.3635878598489952e-07, 'clip_range': 0.27135700606553204, 'vf_coef': 0.6686853408559005, 'max_grad_norm': 2.2249661239867744, 'gae_lambda': 0.9204028864542309, 'n_epochs': 3, 'clip_range_vf': 0.32723395641427766, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 08:59:25,123] Trial 62 finished with value: 39016.0 and parameters: {'lr': 0.00011566031485984825, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.01443323458367029, 'ent_coef': 6.143696084648829e-07, 'clip_range': 0.26667161032386827, 'vf_coef': 0.6713899853691717, 'max_grad_norm': 2.3920584788432855, 'gae_lambda': 0.9032207172506427, 'n_epochs': 3, 'clip_range_vf': 0.3286155965213663, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 09:22:24,112] Trial 63 finished with value: 38906.8 and parameters: {'lr': 8.571218126629228e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 11, 'gamma': 0.021011573584803753, 'ent_coef': 3.0974245053234434e-07, 'clip_range': 0.30771222222901073, 'vf_coef': 0.7152725351259699, 'max_grad_norm': 1.7749736333324169, 'gae_lambda': 0.9212494105856199, 'n_epochs': 3, 'clip_range_vf': 0.3208019479879145, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 09:43:47,727] Trial 64 finished with value: 39027.2 and parameters: {'lr': 6.227650451249944e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 9, 'gamma': 0.009073308658081335, 'ent_coef': 5.47427325708984e-08, 'clip_range': 0.25471231006362394, 'vf_coef': 0.659868418879831, 'max_grad_norm': 1.1430006030737514, 'gae_lambda': 0.8929052881268801, 'n_epochs': 2, 'clip_range_vf': 0.33776333753529425, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 09:50:16,660] Trial 65 pruned.
# [I 2024-02-23 10:11:05,028] Trial 66 finished with value: 39019.6 and parameters: {'lr': 4.166123403093457e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 11, 'gamma': 0.018373520558213265, 'ent_coef': 1.7146813428049848e-08, 'clip_range': 0.2384713903029168, 'vf_coef': 0.5918840972200775, 'max_grad_norm': 2.0206528247995177, 'gae_lambda': 0.9186916739328942, 'n_epochs': 3, 'clip_range_vf': 0.33164925165285813, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 10:17:40,107] Trial 67 pruned.
# [I 2024-02-23 10:38:46,645] Trial 68 finished with value: 39081.0 and parameters: {'lr': 9.999663917428873e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.010479124004581394, 'ent_coef': 1.897256003034392e-10, 'clip_range': 0.24312406106458953, 'vf_coef': 0.38151831915553563, 'max_grad_norm': 7.059895384072355, 'gae_lambda': 0.9060217094396129, 'n_epochs': 3, 'clip_range_vf': 0.2568706071883367, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 11:00:43,560] Trial 69 finished with value: 39027.2 and parameters: {'lr': 9.635961672138702e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.007290081269548681, 'ent_coef': 2.1260580048710907e-10, 'clip_range': 0.2872507790997805, 'vf_coef': 0.37133086813471006, 'max_grad_norm': 4.515739394117473, 'gae_lambda': 0.9024772429118805, 'n_epochs': 4, 'clip_range_vf': 0.3069159788994535, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 11:24:45,518] Trial 70 finished with value: 39091.4 and parameters: {'lr': 0.0002996464326043035, 'exponent_n_steps': 10, 'exponent_batch_size': 10, 'gamma': 0.009319854251031642, 'ent_coef': 5.043890363753148e-10, 'clip_range': 0.2455965359583424, 'vf_coef': 0.43416137488067774, 'max_grad_norm': 7.990512304433064, 'gae_lambda': 0.905388061008009, 'n_epochs': 3, 'clip_range_vf': 0.22047229071116792, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 11:32:27,552] Trial 71 pruned.
# [I 2024-02-23 11:59:25,245] Trial 72 finished with value: 39036.2 and parameters: {'lr': 0.00013081518537345037, 'exponent_n_steps': 11, 'exponent_batch_size': 9, 'gamma': 0.00522232876157718, 'ent_coef': 1.8423656071231837e-10, 'clip_range': 0.24373230678783053, 'vf_coef': 0.3918158565031119, 'max_grad_norm': 7.437769566627629, 'gae_lambda': 0.8927883836886108, 'n_epochs': 3, 'clip_range_vf': 0.23201736665701606, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 12:08:12,304] Trial 73 pruned.
# [I 2024-02-23 12:16:39,004] Trial 74 pruned.
# [I 2024-02-23 12:41:02,200] Trial 75 finished with value: 38861.2 and parameters: {'lr': 0.0004293225580404379, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.003071285675103673, 'ent_coef': 3.2488378696934656e-10, 'clip_range': 0.22708287259137228, 'vf_coef': 0.4050354587379378, 'max_grad_norm': 6.832035233571852, 'gae_lambda': 0.8422292649302536, 'n_epochs': 4, 'clip_range_vf': 0.37501187375718675, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 13:03:46,785] Trial 76 finished with value: 38920.2 and parameters: {'lr': 0.00024313527516037691, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.027125213636145132, 'ent_coef': 7.998112033647591e-10, 'clip_range': 0.21525128953072192, 'vf_coef': 0.3412089264365587, 'max_grad_norm': 3.454753070505701, 'gae_lambda': 0.9315645959291201, 'n_epochs': 3, 'clip_range_vf': 0.18543374023155268, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 13:31:02,949] Trial 77 finished with value: 39118.6 and parameters: {'lr': 5.343001430946255e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 9, 'gamma': 0.03892527984123651, 'ent_coef': 2.3489963988160003e-09, 'clip_range': 0.26172739060865596, 'vf_coef': 0.474262535733854, 'max_grad_norm': 5.880861392000627, 'gae_lambda': 0.888373985280663, 'n_epochs': 3, 'clip_range_vf': 0.2463923819254589, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 13:39:29,032] Trial 78 pruned.
# [I 2024-02-23 14:02:58,935] Trial 79 finished with value: 39024.8 and parameters: {'lr': 5.314371048447887e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 11, 'gamma': 0.01453637907763551, 'ent_coef': 5.923297888509146e-10, 'clip_range': 0.2805226372257844, 'vf_coef': 0.4622010084503272, 'max_grad_norm': 5.758778517431151, 'gae_lambda': 0.8515807006690526, 'n_epochs': 4, 'clip_range_vf': 0.24595856196304944, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 14:26:09,505] Trial 80 finished with value: 39097.4 and parameters: {'lr': 0.00010514010253096207, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.008902930406007755, 'ent_coef': 9.222385397292304e-09, 'clip_range': 0.23377783194265198, 'vf_coef': 0.44719211796598923, 'max_grad_norm': 4.755787672778316, 'gae_lambda': 0.8962741620668996, 'n_epochs': 3, 'clip_range_vf': 0.2648671315231805, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 14:49:24,608] Trial 81 finished with value: 39053.0 and parameters: {'lr': 0.00010436929865521811, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.008457408821632982, 'ent_coef': 1.0614771025642874e-08, 'clip_range': 0.2620642605086282, 'vf_coef': 0.4455369327204763, 'max_grad_norm': 4.563747700880823, 'gae_lambda': 0.8967331061897911, 'n_epochs': 3, 'clip_range_vf': 0.257930563359348, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 15:12:53,747] Trial 82 finished with value: 39046.4 and parameters: {'lr': 0.00015362728105909775, 'exponent_n_steps': 13, 'exponent_batch_size': 9, 'gamma': 0.006653323978234496, 'ent_coef': 2.6487380836998945e-08, 'clip_range': 0.23749670312166107, 'vf_coef': 0.48038688446934397, 'max_grad_norm': 8.251581912988557, 'gae_lambda': 0.8743948112294491, 'n_epochs': 3, 'clip_range_vf': 0.2662610798267968, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 15:20:09,380] Trial 83 pruned.
# [I 2024-02-23 15:43:49,204] Trial 84 finished with value: 39055.6 and parameters: {'lr': 0.00011811529477549364, 'exponent_n_steps': 12, 'exponent_batch_size': 11, 'gamma': 0.0022089090217939965, 'ent_coef': 3.5196613007870473e-09, 'clip_range': 0.24524290394243078, 'vf_coef': 0.4211871966489985, 'max_grad_norm': 3.79186450997168, 'gae_lambda': 0.8852352653611718, 'n_epochs': 4, 'clip_range_vf': 0.21275355315732591, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 16:05:16,773] Trial 85 finished with value: 39054.8 and parameters: {'lr': 6.830539727874705e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 9, 'gamma': 0.004357976325231764, 'ent_coef': 1.300690692093421e-09, 'clip_range': 0.29444450354232593, 'vf_coef': 0.4314962943331555, 'max_grad_norm': 4.7374676775384215, 'gae_lambda': 0.9286831150373318, 'n_epochs': 3, 'clip_range_vf': 0.34696172400096936, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 16:28:50,401] Trial 86 finished with value: 38979.2 and parameters: {'lr': 0.0002760913560287921, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.01545735226009177, 'ent_coef': 9.697120290728835e-09, 'clip_range': 0.19717016488091954, 'vf_coef': 0.4979897333646354, 'max_grad_norm': 6.28588222648277, 'gae_lambda': 0.906998189276856, 'n_epochs': 2, 'clip_range_vf': 0.28183979502677164, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 2048, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 16:38:32,120] Trial 87 pruned.
# [I 2024-02-23 16:45:11,593] Trial 88 pruned.
# [I 2024-02-23 17:07:35,342] Trial 89 finished with value: 38989.6 and parameters: {'lr': 0.0008728394411965699, 'exponent_n_steps': 9, 'exponent_batch_size': 11, 'gamma': 0.005829244225327296, 'ent_coef': 1.9160297263648186e-09, 'clip_range': 0.24659646729178336, 'vf_coef': 0.45208492945546336, 'max_grad_norm': 0.010738543526917013, 'gae_lambda': 0.9240651210284286, 'n_epochs': 7, 'clip_range_vf': 0.32087456856237107, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 17:20:52,826] Trial 90 pruned.
# [I 2024-02-23 17:27:41,779] Trial 91 pruned.
# [I 2024-02-23 17:49:15,296] Trial 92 finished with value: 39026.4 and parameters: {'lr': 4.772675718851839e-05, 'exponent_n_steps': 12, 'exponent_batch_size': 10, 'gamma': 0.0015112231345701637, 'ent_coef': 1.3123754332424442e-10, 'clip_range': 0.1321480596006623, 'vf_coef': 0.4292813192620242, 'max_grad_norm': 3.4628681010746303, 'gae_lambda': 0.9131316077222004, 'n_epochs': 3, 'clip_range_vf': 0.26185287674055946, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 18:09:38,188] Trial 93 finished with value: 38803.0 and parameters: {'lr': 0.00014701411781082433, 'exponent_n_steps': 11, 'exponent_batch_size': 10, 'gamma': 0.02676134816877567, 'ent_coef': 3.70471710933835e-10, 'clip_range': 0.1596498959930509, 'vf_coef': 0.47033742348117313, 'max_grad_norm': 0.338247932581595, 'gae_lambda': 0.8017779378939192, 'n_epochs': 3, 'clip_range_vf': 0.2712377221542323, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 18:16:39,563] Trial 94 pruned.
# [I 2024-02-23 18:23:22,699] Trial 95 pruned.
# [I 2024-02-23 18:46:06,784] Trial 96 finished with value: 39105.2 and parameters: {'lr': 9.687950333673219e-05, 'exponent_n_steps': 13, 'exponent_batch_size': 10, 'gamma': 0.038755726098815085, 'ent_coef': 1.1641850761434039e-09, 'clip_range': 0.1913401459155483, 'vf_coef': 0.5262811319721159, 'max_grad_norm': 0.257357843523452, 'gae_lambda': 0.9008157999102618, 'n_epochs': 4, 'clip_range_vf': 0.252349215827311, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 18:53:23,976] Trial 97 pruned.
# [I 2024-02-23 19:19:56,716] Trial 98 finished with value: 39098.6 and parameters: {'lr': 0.00010548564590256385, 'exponent_n_steps': 14, 'exponent_batch_size': 11, 'gamma': 0.008368684909276166, 'ent_coef': 5.323522777924673e-09, 'clip_range': 0.2384726878350025, 'vf_coef': 0.5320409815504958, 'max_grad_norm': 0.14232946700744728, 'gae_lambda': 0.8581958328792563, 'n_epochs': 6, 'clip_range_vf': 0.22902504553363107, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 19:50:47,844] Trial 99 finished with value: 38933.4 and parameters: {'lr': 0.00019030473348053144, 'exponent_n_steps': 14, 'exponent_batch_size': 10, 'gamma': 0.05961741350446276, 'ent_coef': 4.389626808386267e-10, 'clip_range': 0.23928873719772115, 'vf_coef': 0.5162169865155305, 'max_grad_norm': 0.17361551044285606, 'gae_lambda': 0.8437564184690094, 'n_epochs': 6, 'clip_range_vf': 0.398716624347156, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 20:01:42,291] Trial 100 pruned.
# [I 2024-02-23 20:32:12,235] Trial 101 finished with value: 39017.8 and parameters: {'lr': 5.459509943015498e-05, 'exponent_n_steps': 13, 'exponent_batch_size': 11, 'gamma': 0.009769409311582171, 'ent_coef': 5.363836644068451e-09, 'clip_range': 0.2510417187698822, 'vf_coef': 0.5435776325283632, 'max_grad_norm': 0.15872986275444265, 'gae_lambda': 0.8215904518102678, 'n_epochs': 5, 'clip_range_vf': 0.23262662039414328, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 21:05:51,314] Trial 102 finished with value: 39006.4 and parameters: {'lr': 9.503794486586161e-05, 'exponent_n_steps': 14, 'exponent_batch_size': 11, 'gamma': 0.008088940268313007, 'ent_coef': 9.342797246333625e-09, 'clip_range': 0.2593724300726253, 'vf_coef': 0.5055433793106713, 'max_grad_norm': 0.2501123868597691, 'gae_lambda': 0.8699984030098796, 'n_epochs': 6, 'clip_range_vf': 0.24247828498972457, 'net_arch': 'big', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 21:16:19,531] Trial 103 pruned.
# [I 2024-02-23 21:25:52,696] Trial 104 pruned.
# d:\98_phD_Files\Projeto 006 - Artigo rede regular iTwo\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1024, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(
# [I 2024-02-23 21:35:43,273] Trial 105 pruned.
# [I 2024-02-23 21:45:29,766] Trial 106 pruned.
# [I 2024-02-23 22:16:04,542] Trial 107 finished with value: 38891.8 and parameters: {'lr': 0.0002720270033707979, 'exponent_n_steps': 14, 'exponent_batch_size': 10, 'gamma': 0.02198639642889282, 'ent_coef': 7.111327529760585e-08, 'clip_range': 0.21786348084218354, 'vf_coef': 0.5249421474924312, 'max_grad_norm': 0.281303619065285, 'gae_lambda': 0.8931400217338268, 'n_epochs': 7, 'clip_range_vf': 0.2165277094785752, 'net_arch': 'big', 'activation_fn': 'tanh'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 22:47:39,744] Trial 108 finished with value: 39028.8 and parameters: {'lr': 6.05915538184389e-05, 'exponent_n_steps': 11, 'exponent_batch_size': 11, 'gamma': 0.0037379307058184046, 'ent_coef': 4.756379680142448e-10, 'clip_range': 0.24330620005213544, 'vf_coef': 0.5154234110465838, 'max_grad_norm': 0.138519583156243, 'gae_lambda': 0.9525191124426955, 'n_epochs': 7, 'clip_range_vf': 0.3832334365698934, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
# [I 2024-02-23 22:55:46,994] Trial 109 pruned.
# [I 2024-02-23 23:23:57,103] Trial 110 finished with value: 38863.4 and parameters: {'lr': 8.547034271340271e-05, 'exponent_n_steps': 10, 'exponent_batch_size': 10, 'gamma': 0.010600686387259733, 'ent_coef': 7.848368418147114e-10, 'clip_range': 0.1910881254806249, 'vf_coef': 0.5512451438145753, 'max_grad_norm': 4.115186479407126, 'gae_lambda': 0.9433868603378078, 'n_epochs': 3, 'clip_range_vf': 0.24864944059988617, 'net_arch': 'small', 'activation_fn': 'LeakyReLU'}. Best is trial 5 with value: 39121.2.
